# %%
import pandas as pd

# %%
data = [
    {
        "Start": 1,
        "Qual Speed": 234.220,
        "Driver": "Scott McLaughlin",
        "Car Name": "Team Penske",
        "Model": "Chevy"
    },
    {
        "Start": 2,
        "Qual Speed": 233.917,
        "Driver": "Will Power",
        "Car Name": "Team Penske",
        "Model": "Chevy"
    },
    {
        "Start": 3,
        "Qual Speed": 233.808,
        "Driver": "Josef Newgarden",
        "Car Name": "Team Penske",
        "Model": "Chevy"
    },
    {
        "Start": 4,
        "Qual Speed": 233.090,
        "Driver": "Alexander Rossi",
        "Car Name": "Arrow McLaren",
        "Model": "Chevy"
    },
    {
        "Start": 5,
        "Qual Speed": 232.846,
        "Driver": "Kyle Larson",
        "Car Name": "Arrow McLaren",
        "Model": "Chevy"
    },
    {
        "Start": 6,
        "Qual Speed": 232.692,
        "Driver": "Santino Ferrucci",
        "Car Name": "A.J. Foyt Enterprises",
        "Model": "Chevy"
    },
    {
        "Start": 7,
        "Qual Speed": 232.610,
        "Driver": "Rinus VeeKay",
        "Car Name": "Ed Carpenter Racing",
        "Model": "Chevy"
    },
    {
        "Start": 8,
        "Qual Speed": 232.584,
        "Driver": "Pato O'Ward",
        "Car Name": "Arrow McLaren",
        "Model": "Chevy"
    },
    {
        "Start": 9,
        "Qual Speed": 232.305,
        "Driver": "Felix Rosenqvist",
        "Car Name": "Meyer Shank Racing",
        "Model": "Honda"
    },
    {
        "Start": 10,
        "Qual Speed": 232.171,
        "Driver": "Takuma Sato",
        "Car Name": "Rahal Letterman Lanigan Racing",
        "Model": "Honda"
    },
    {
        "Start": 11,
        "Qual Speed": 230.993,
        "Driver": "Kyle Kirkwood",
        "Car Name": "Andretti Global",
        "Model": "Honda"
    },
    {
        "Start": 12,
        "Qual Speed": 230.567,
        "Driver": "Ryan Hunter-Reay",
        "Car Name": "Dreyer & Reinbold Racing / Cusick Motorsports",
        "Model": "Chevy"
    },
    {
        "Start": 13,
        "Qual Speed": 232.316,
        "Driver": "Colton Herta",
        "Car Name": "Andretti Global w/ Curb-Agajanian",
        "Model": "Honda"
    },
    {
        "Start": 14,
        "Qual Speed": 232.306,
        "Driver": "Alex Palou",
        "Car Name": "Chip Ganassi Racing",
        "Model": "Honda"
    },
    {
        "Start": 15,
        "Qual Speed": 232.230,
        "Driver": "Callum Ilott",
        "Car Name": "Arrow McLaren",
        "Model": "Chevy"
    },
    {
        "Start": 16,
        "Qual Speed": 232.183,
        "Driver": "Marcus Armstrong",
        "Car Name": "Chip Ganassi Racing",
        "Model": "Honda"
    },
    {
        "Start": 17,
        "Qual Speed": 232.017,
        "Driver": "Ed Carpenter",
        "Car Name": "Ed Carpenter Racing",
        "Model": "Chevy"
    },
    {
        "Start": 18,
        "Qual Speed": 231.948,
        "Driver": "Kyffin Simpson",
        "Car Name": "Chip Ganassi Racing",
        "Model": "Honda"
    },
    {
        "Start": 19,
        "Qual Speed": 231.890,
        "Driver": "Marco Andretti",
        "Car Name": "Andretti Herta w/ Marco & Curb-Agajanian",
        "Model": "Honda"
    },
    {
        "Start": 20,
        "Qual Speed": 231.871,
        "Driver": "Helio Castroneves",
        "Car Name": "Meyer Shank Racing",
        "Model": "Honda"
    },
    {
        "Start": 21,
        "Qual Speed": 231.851,
        "Driver": "Scott Dixon",
        "Car Name": "Chip Ganassi Racing",
        "Model": "Honda"
    },
    {
        "Start": 22,
        "Qual Speed": 231.847,
        "Driver": "Agustin Canapino",
        "Car Name": "Juncos Hollinger Racing",
        "Model": "Chevy"
    },
    {
        "Start": 23,
        "Qual Speed": 231.826,
        "Driver": "Sting Ray Robb",
        "Car Name": "A.J. Foyt Enterprises",
        "Model": "Chevy"
    },
    {
        "Start": 24,
        "Qual Speed": 231.682,
        "Driver": "Christian Rasmussen",
        "Car Name": "Ed Carpenter Racing",
        "Model": "Chevy"
    },
    {
        "Start": 25,
        "Qual Speed": 231.578,
        "Driver": "Tom Blomqvist",
        "Car Name": "Meyer Shank Racing",
        "Model": "Honda"
    },
    {
        "Start": 26,
        "Qual Speed": 231.514,
        "Driver": "Romain Grosjean",
        "Car Name": "Juncos Hollinger Racing",
        "Model": "Chevy"
    },
    {
        "Start": 27,
        "Qual Speed": 231.506,
        "Driver": "Linus Lundqvist",
        "Car Name": "Chip Ganassi Racing",
        "Model": "Honda"
    },
    {
        "Start": 28,
        "Qual Speed": 231.465,
        "Driver": "Christian Lundgaard",
        "Car Name": "Rahal Letterman Lanigan Racing",
        "Model": "Honda"
    },
    {
        "Start": 29,
        "Qual Speed": 231.243,
        "Driver": "Conor Daly",
        "Car Name": "Dreyer & Reinbold Racing / Cusick Motorsports",
        "Model": "Chevy"
    },
    {
        "Start": 30,
        "Qual Speed": 231.100,
        "Driver": "Pietro Fittipaldi",
        "Car Name": "Rahal Letterman Lanigan Racing",
        "Model": "Honda"
    },
    {
        "Start": 31,
        "Qual Speed": 230.092,
        "Driver": "Katherine Legge",
        "Car Name": "Dale Coyne Racing",
        "Model": "Honda"
    },
    {
        "Start": 32,
        "Qual Speed": 230.027,
        "Driver": "Marcus Ericsson",
        "Car Name": "Andretti Global",
        "Model": "Honda"
    },
    {
        "Start": 33,
        "Qual Speed": 229.974,
        "Driver": "Graham Rahal",
        "Car Name": "Rahal Letterman Lanigan Racing",
        "Model": "Honda"
    }
]

# %% [markdown]
# The data was sourced from https://www.indianapolismotorspeedway.com/events/indy500/event-info/live-grid
#
# The data was parsed using GPT4o by providing the model screenshotted images of the starting grid, and giving the following prompt
#
# ```
# Going in order of driver start position (1st - 33rd, row 1 - row 9) parse the following information.
#
# {
# 	"Start": // start position
# 	"Qual Speed": // top qualifying speed
# 	"Driver": // driver name, with standard name capitalization
# 	"Car Name": // sponser / team
# 	"Model":  // chevy or honda, as indicated by the image of the logo
# }
#
# ensure that each driver's starting position is accurate and reflects their order from top to bottom, left to right. your output should be a list of 32 objects as specified above.
# ```

# %%
og_column_names = ['Start', 'Qual Speed', 'Driver', 'Car Name', 'Model'] 
new_column_names = ['start', 'qual_speed', 'driver', 'car_name', 'model']
column_mapper = {og: new for og, new in zip(og_column_names, new_column_names)}

df = (
    pd.DataFrame(data)
    .rename(columns=column_mapper)
    .assign(year=2024)
    .assign(model=lambda df_: df_.model.apply(lambda m: 'Dallara/' + m))
)

df.to_csv(f'race_stats_2024.csv', index=False)

df
# Out:
#     start  qual_speed               driver  \
# 0       1     234.220     Scott McLaughlin
# 1       2     233.917           Will Power
# 2       3     233.808      Josef Newgarden
# 3       4     233.090      Alexander Rossi
# 4       5     232.846          Kyle Larson
# 5       6     232.692     Santino Ferrucci
# 6       7     232.610         Rinus VeeKay
# 7       8     232.584          Pato O'Ward
# 8       9     232.305     Felix Rosenqvist
# 9      10     232.171          Takuma Sato
# 10     11     230.993        Kyle Kirkwood
# 11     12     230.567     Ryan Hunter-Reay
# 12     13     232.316         Colton Herta
# 13     14     232.306           Alex Palou
# 14     15     232.230         Callum Ilott
# 15     16     232.183     Marcus Armstrong
# 16     17     232.017         Ed Carpenter
# 17     18     231.948       Kyffin Simpson
# 18     19     231.890       Marco Andretti
# 19     20     231.871    Helio Castroneves
# 20     21     231.851          Scott Dixon
# ...
