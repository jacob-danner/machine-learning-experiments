# %%
import polars as pl
import torch
import numpy as np
import duckdb

# %% [markdown]
# ## Image Tensors -> DuckDB

# %% [markdown]
# This assumes the images have been loaded into tensors.

# %% [markdown]
# ### Load the tensors and labels into a dataframe

# %%
n_images = 1000
images = torch.randn(n_images, 3, 28, 28)

list_of_images = [image.flatten().numpy() for image in images]

df = pl.DataFrame(
    {
        "image_tensors": list_of_images,
        "labels": [0 if i % 2 == 0 else 1 for i in range(n_images)],
    }
)

df.head(4)
# Out:
# shape: (4, 2)
# ┌───────────────────────────────────┬────────┐
# │ image_tensors                     ┆ labels │
# │ ---                               ┆ ---    │
# │ list[f32]                         ┆ i64    │
# ╞═══════════════════════════════════╪════════╡
# │ [0.078221, 0.006165, … -1.637237… ┆ 0      │
# │ [-0.986142, 1.431071, … -0.78276… ┆ 1      │
# │ [-0.11733, -0.171572, … -1.52689… ┆ 0      │
# │ [-1.438237, 0.67865, … -1.042472… ┆ 1      │
# └───────────────────────────────────┴────────┘

# %% [markdown]
# ### Load the dataframe to duckdb

# %%
con = duckdb.connect('image_dataset.db')

con.sql(f'CREATE TABLE IMAGES AS SELECT * FROM df')

con.sql('FROM images').show()
# Out:
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────┬────────┐
# │                                                image_tensors                                                │ labels │
# │                                                   float[]                                                   │ int64  │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────┤
# │ [0.07822117, 0.006164769, -0.52732444, -0.33928436, 0.2004719, 0.44075122, -0.017990295, 1.2530198, -0.42…  │      0 │
# │ [-0.9861415, 1.431071, -1.919284, 1.1519945, 0.80238366, -1.218601, -0.09066243, -2.352858, 1.1527617, 1.…  │      1 │
# │ [-0.11733001, -0.17157178, -0.22701412, 0.2785775, 0.11213446, 0.50116795, 1.2962005, -1.600458, 0.689514…  │      0 │
# │ [-1.4382374, 0.6786499, 2.12278, 1.2003614, -0.63969743, -0.026586259, 0.48129764, -0.43329766, 1.7827098…  │      1 │
# │ [-0.62999773, 0.024809627, 1.1581205, -1.3106352, -0.594826, 0.2236242, 0.7046172, 0.71101755, 0.49328837…  │      0 │
# │ [0.46220872, 0.91336167, 1.8489559, 0.45599872, -0.8612786, 2.125842, 0.19960935, 1.2993292, -1.0482051, …  │      1 │
# │ [-0.51613903, -0.9696867, -0.24669431, -0.9941569, 0.20048912, 1.509086, 0.12734555, 1.2676108, -0.343920…  │      0 │
# │ [-0.9853544, 0.73236567, 1.6120052, 0.48973495, 0.46618035, 0.23290996, 0.43648317, -0.5392371, -0.151593…  │      1 │
# │ [0.7422001, 1.7230462, 1.7472236, 0.87732494, -1.3173485, -1.3048415, 2.305655, 0.33554673, -0.20555073, …  │      0 │
# │ [-0.66161007, 0.56246126, -0.31330597, 0.37479386, -0.21943137, 0.6938758, -1.2989436, 1.2038385, -0.7944…  │      1 │
# │                                                      ·                                                      │      · │
# │                                                      ·                                                      │      · │
# │                                                      ·                                                      │      · │
# │ [1.1660343, 1.6260215, 0.08087334, 0.54892695, 0.7598151, 0.8556536, 1.8324896, 0.21184397, 0.47623548, 0…  │      0 │
# │ [-0.6868406, 0.06793986, 1.7576064, 0.7041302, -0.18558045, -0.47247186, -0.0068489225, -0.956739, -0.208…  │      1 │
# │ [0.48409507, -0.05061343, 0.4165221, -0.6525228, 1.7720727, 0.33268356, -0.16400482, -0.15251873, 0.12290…  │      0 │
# │ [-0.33797368, -0.62714964, 1.2297336, 1.1864105, -1.8953146, 0.8706288, -0.02712709, -0.12581514, -0.1107…  │      1 │
# │ [0.6634185, -1.2473322, 0.43879047, -0.8663063, 1.9043393, -0.021421375, -0.0873983, 0.2483866, 1.821852,…  │      0 │
# │ [-0.64432967, 0.08689963, -0.95667195, 0.1282605, -0.3962935, 0.4808583, 0.8692312, -0.5275543, 0.1002033…  │      1 │
# │ [-0.48077092, -1.1287731, -0.33509928, 1.0365618, -0.6653293, -0.69193655, 0.1974122, -0.6571262, -0.1792…  │      0 │
# │ [-1.471502, 0.24910358, -0.8180453, 1.065555, -1.3125507, 0.7014604, -0.6589248, 0.106230974, 1.615995, -…  │      1 │
# │ [-0.26260898, -1.2938471, 0.68828106, 1.2555567, -0.19217211, 0.092744544, 0.4866469, -0.3422346, 0.81773…  │      0 │
# │ [-0.97473955, 0.44656628, -0.9540312, -1.3961171, -2.7537894, 2.3173249, -0.18190743, 0.52347904, -0.1250…  │      1 │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────┴────────┤
# │ 1000 rows (20 shown)                                                                                       2 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## DuckDB -> Image Tensors

# %%
df = pl.DataFrame(con.sql('FROM images').to_df())

retrieved = (
    torch.tensor(df['image_tensors'])
    .view(-1, 3, 28, 28)
)

retrieved.shape
# Out:
# torch.Size([1000, 3, 28, 28])
